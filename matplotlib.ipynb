# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(1,121,200)

# %%
x
# Out:
# array([  1.        ,   1.60301508,   2.20603015,   2.80904523,
#          3.4120603 ,   4.01507538,   4.61809045,   5.22110553,
#          5.8241206 ,   6.42713568,   7.03015075,   7.63316583,
#          8.2361809 ,   8.83919598,   9.44221106,  10.04522613,
#         10.64824121,  11.25125628,  11.85427136,  12.45728643,
#         13.06030151,  13.66331658,  14.26633166,  14.86934673,
#         15.47236181,  16.07537688,  16.67839196,  17.28140704,
#         17.88442211,  18.48743719,  19.09045226,  19.69346734,
#         20.29648241,  20.89949749,  21.50251256,  22.10552764,
#         22.70854271,  23.31155779,  23.91457286,  24.51758794,
#         25.12060302,  25.72361809,  26.32663317,  26.92964824,
#         27.53266332,  28.13567839,  28.73869347,  29.34170854,
#         29.94472362,  30.54773869,  31.15075377,  31.75376884,
#         32.35678392,  32.95979899,  33.56281407,  34.16582915,
#         34.76884422,  35.3718593 ,  35.97487437,  36.57788945,
#         37.18090452,  37.7839196 ,  38.38693467,  38.98994975,
#         39.59296482,  40.1959799 ,  40.79899497,  41.40201005,
#         42.00502513,  42.6080402 ,  43.21105528,  43.81407035,
#         44.41708543,  45.0201005 ,  45.62311558,  46.22613065,
#         46.82914573,  47.4321608 ,  48.03517588,  48.63819095,
#         49.24120603,  49.84422111,  50.44723618,  51.05025126,
#         51.65326633,  52.25628141,  52.85929648,  53.46231156,
#         54.06532663,  54.66834171,  55.27135678,  55.87437186,
#         56.47738693,  57.08040201,  57.68341709,  58.28643216,
#         58.88944724,  59.49246231,  60.09547739,  60.69849246,
#         61.30150754,  61.90452261,  62.50753769,  63.11055276,
#         63.71356784,  64.31658291,  64.91959799,  65.52261307,
#         66.12562814,  66.72864322,  67.33165829,  67.93467337,
#         68.53768844,  69.14070352,  69.74371859,  70.34673367,
#         70.94974874,  71.55276382,  72.15577889,  72.75879397,
#         73.36180905,  73.96482412,  74.5678392 ,  75.17085427,
#         75.77386935,  76.37688442,  76.9798995 ,  77.58291457,
#         78.18592965,  78.78894472,  79.3919598 ,  79.99497487,
#         80.59798995,  81.20100503,  81.8040201 ,  82.40703518,
#         83.01005025,  83.61306533,  84.2160804 ,  84.81909548,
#         85.42211055,  86.02512563,  86.6281407 ,  87.23115578,
#         87.83417085,  88.43718593,  89.04020101,  89.64321608,
#         90.24623116,  90.84924623,  91.45226131,  92.05527638,
#         92.65829146,  93.26130653,  93.86432161,  94.46733668,
#         95.07035176,  95.67336683,  96.27638191,  96.87939698,
#         97.48241206,  98.08542714,  98.68844221,  99.29145729,
#         99.89447236, 100.49748744, 101.10050251, 101.70351759,
#        102.30653266, 102.90954774, 103.51256281, 104.11557789,
#        104.71859296, 105.32160804, 105.92462312, 106.52763819,
#        107.13065327, 107.73366834, 108.33668342, 108.93969849,
#        109.54271357, 110.14572864, 110.74874372, 111.35175879,
#        111.95477387, 112.55778894, 113.16080402, 113.7638191 ,
#        114.36683417, 114.96984925, 115.57286432, 116.1758794 ,
#        116.77889447, 117.38190955, 117.98492462, 118.5879397 ,
#        119.19095477, 119.79396985, 120.39698492, 121.        ])

# %%
y=np.sin(x)

# %%
plt.plot(x,y,'r')
plt.grid()

# %%
plt.plot(x,y)
plt.xlabel("This is my x data")
plt.ylabel("This is my y data")
plt.title("This is my table")
plt.show()

# %%
x=np.random.rand(50)
y=np.random.rand(50)
colors=np.random.rand(50)
sizes=np.random.rand(50)*100

# %%
plt.scatter(x,y,c=colors,s=sizes,alpha =.4)
plt.xlabel("This is x label")
plt.ylabel("This is y label")
plt.title("This is my title")
# Out:
# Text(0.5, 1.0, 'This is my title')

# %%
x=['a','b','c','d','e','f']
y=np.random.rand(6)

# %%
plt.barh(x,y)
plt.xlabel("This is the x label")
plt.ylabel("This is the y label")
plt.title("This is the title")
# Out:
# Text(0.5, 1.0, 'This is the title')

# %%
data=[1,2,2,2,3,2,2,1,1,5,6,7,3,4,6,5,3]
plt.hist(data)
# Out:
# (array([3., 5., 0., 3., 0., 1., 2., 0., 2., 1.]),
#  array([1. , 1.6, 2.2, 2.8, 3.4, 4. , 4.6, 5.2, 5.8, 6.4, 7. ]),
#  <BarContainer object of 10 artists>)

# %%
x=np.random.rand(50)
y=np.random.rand(50)
z=np.random.rand(50)

fig=plt.figure()
ax=fig.add_subplot(projection="3d")
ax.scatter(x,y)
